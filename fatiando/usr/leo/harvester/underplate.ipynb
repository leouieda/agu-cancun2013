# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
"""                                                                             
GravMag: 3D inversion in spherical coordinates using harvester and tesseroids   
"""
from IPython.display import Image
from fatiando import gravmag, gridder, logger, mesher, utils
from fatiando.vis import mpl, myv
import cPickle as pickle

# %%
log = logger.get()

# %%
props = {'density':1000}
model = [mesher.Tesseroid(-58, -52, -22, -18, -30000, -50000, props)]

# %%
myv.figure(zdown=False)
myv.tesseroids(model, 'density')
myv.earth(opacity=0.4)
myv.continents()
myv.show()

# %%
bounds = [-70, -40, -40, 0, -10000, -90000]
shape = (100, 100)
lons, lats, heights = gridder.regular(bounds[:4], shape, z=250000)
gz = utils.contaminate(gravmag.tesseroid.gz(lons, lats, heights, model), 0.01, percent=True)
# Out:
# Generating regular grid:
#   area = (x1, x2, y1, y2) = (-70, -40, -40, 0)
#   shape = (ny, nx) = (100, 100)
#   spacing = (dy, dx) = (0.40404040404040403, 0.30303030303030304)
#   points = nx*ny = 10000
#   z = 250000
# Contaminating data with Gaussian noise:
#   noise level = 1 percent
#   noise stddev = 2.43973704228

# %%
mpl.figure(figsize=(10, 8))
bm = mpl.basemap(bounds[:4], 'ortho')
bm.drawcoastlines()
bm.drawmapboundary()
mpl.contourf(lons, lats, gz, shape, 30, basemap=bm)
cb = mpl.colorbar()
cb.set_label('mGal')

# %%
mesh = mesher.TesseroidMesh(bounds, (30, 80, 80))

# %%
seeds = gravmag.harvester.sow([[-55, -20, -35000, props]], mesh)
# Out:
# Fetching seeds from mesh:
#   points given: 1
#   unique seeds found: 1

# %%
myv.figure(zdown=False)
myv.tesseroids(model, style='wireframe')
myv.tesseroids([mesh[s.i] for s in seeds])
myv.earth(opacity=0.4)
myv.continents()
myv.show()

# %%
data = [gravmag.harvester.Gz(lons, lats, heights, gz, meshtype='tesseroid')]

# %%
estimate, predicted = gravmag.harvester.harvest(data, seeds, mesh, compactness=1, threshold=0.001)
# Out:
# Harvesting inversion results:
#   compactness: 1
#   threshold: 0.001
#   # of seeds: 1
#   # of data types: 1
#   initial goal function: 1.17627
#   initial data misfit: 0.998822
#   Running...
#   # of accretions: 955
#   final goal function: 320.727
#   final compactness regularizing function: 5057.65
#   final data misfit: 0.0668518
#   time it took: 0h 1m 21.40664s

# %%
mesh.addprop('density', estimate['density'])

# %%
result = mesher.vremove(0, 'density', mesh)

# %%
top = max(t.top for t in result)
bottom = min(t.bottom for t in result)
print "top:", top
print "bottom:", bottom
# Out:
# top: -28666.6666667
# bottom: -50000.0

# %%
mpl.figure(figsize=(20, 8))
mpl.subplot(1, 2, 1)
bm = mpl.basemap(bounds[:4], 'ortho')
bm.drawcoastlines()
bm.drawmapboundary()
levels = mpl.contour(lons, lats, gz, shape, 8, basemap=bm, color='k')
mpl.contour(lons, lats, predicted[0], shape, levels, basemap=bm, color='r')

mpl.subplot(1, 2, 2)
mpl.hist(gz - predicted[0], bins=20)
# Out:
# (array([   4,    3,   13,   46,  107,  284,  521,  821, 1296, 1514, 1587,
#        1375, 1089,  683,  365,  180,   71,   27,   11,    3]),
#  array([-9.88193063, -8.91295868, -7.94398674, -6.9750148 , -6.00604286,
#        -5.03707091, -4.06809897, -3.09912703, -2.13015508, -1.16118314,
#        -0.1922112 ,  0.77676075,  1.74573269,  2.71470463,  3.68367657,
#         4.65264852,  5.62162046,  6.5905924 ,  7.55956435,  8.52853629,
#         9.49750823]),
#  <a list of 20 Patch objects>)

# %%
scene = myv.figure(zdown=False, size=(800, 800))
plot = myv.tesseroids(model, 'density', style='wireframe', linewidth=5)
plot.actor.mapper.scalar_visibility = False
plot = myv.tesseroids(model, 'density', opacity=0.3)
plot.actor.mapper.scalar_visibility = False
myv.tesseroids([mesh[s.i] for s in seeds], 'density')
myv.tesseroids(result, 'density')
#myv.earth(opacity=0.4)
#myv.continents()
scene.scene.camera.position = [4314090.8897179738, -4574921.4583690045, -3376663.3767931666]
scene.scene.camera.focal_point = [3392001.4560458101, -4819737.5867900942, -2133149.2428752407]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.25543320655423613, -0.96682625284746559, -0.00093476967701495994]
scene.scene.camera.clipping_range = [651034.28734313953, 2663591.9954993557]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()
myv.savefig('underplate.png')
myv.show()

# %%
Image(filename='underplate.png')

# %%
with open('underplate.pickle', 'w') as f:
    pickle.dump([estimate, predicted], f)
